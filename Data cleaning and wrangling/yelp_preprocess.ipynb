# %%
# This file preprocesses the data from the yelp dataset. We will break down each individual dataset:

import pandas as pd
import numpy as np

# %% [markdown]
# ## We will start with the 'businesses' dataset

# %%
res_df = pd.read_json("yelp_academic_dataset_business.json", lines=True)
display(res_df)
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# ...

# %%
desired_categories = ['Restaurants', 'Food', 'Coffee', 'Tea']
res_df = res_df[res_df['categories'].str.contains('|'.join(desired_categories), case=False, na=False)]

# %%
rows_with_null = res_df[res_df.isnull().any(axis=1)]
# rows_with_null

# %%
null_categories = res_df[res_df['categories'].isnull()]
# null_categories

# %%
res_df = res_df.dropna(subset=['categories'])

# %%
res_df.isna().sum()
res_df['attributes'].fillna({}, inplace=True)
res_df.isna().sum()
# Out:
# business_id        0
# name               0
# address            0
# city               0
# state              0
# postal_code        0
# latitude           0
# longitude          0
# stars              0
# review_count       0
# is_open            0
# attributes       887
# categories         0
# hours           9421
# dtype: int64

# %%
res_df['attributes'] = res_df['attributes'].apply(lambda x: {} if pd.isnull(x) else x)

# %%
res_df.drop('hours', axis=1, inplace=True)
res_df.isna().sum()
# Out:
# business_id     0
# name            0
# address         0
# city            0
# state           0
# postal_code     0
# latitude        0
# longitude       0
# stars           0
# review_count    0
# is_open         0
# attributes      0
# categories      0
# dtype: int64

# %%
res_df.to_csv('yelp_restaurants.csv', index=False)

# %% [markdown]
# ## Now we will move onto the yelp_academic_dataset_tips ##
# This dataset has a review_id, business_id and a tip_id

# %%
tip_df = pd.read_json("yelp_academic_dataset_tip.json", lines=True)
display(tip_df)
# Out:
#                        user_id             business_id  \
# 0       AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1       NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2       -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3       FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4       ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# ...                        ...                     ...
# 908910  eYodOTF8pkqKPzHkcxZs-Q  3lHTewuKFt5IImbXJoFeDQ
# 908911  1uxtQAuJ2T5Xwa_wp7kUnA  OaGf0Dp56ARhQwIDT90w_g
# 908912  v48Spe6WEpqehsF2xQADpg  hYnMeAO77RGyTtIzUSKYzQ
# 908913  ckqKGM2hl7I9Chp5IpAhkw  s2eyoTuJrcP7I_XyjdhUHQ
# 908914  4tF1CWdMxvvwpUIgGsDygA  _cb1Vg1NIWry8UA0jyuXnQ
#
#                                                      text                date  \
# 0                          Avengers time with the ladies. 2012-05-18 02:17:21
# 1       They have lots of good deserts and tasty cuban... 2013-02-05 18:35:10
# ...

# %%
tip_df.isna().sum()
# Out:
# user_id             0
# business_id         0
# text                0
# date                0
# compliment_count    0
# dtype: int64

# %%
filtered_tip_df = tip_df[tip_df['business_id'].isin(res_df['business_id'])]
display(filtered_tip_df)
# Out:
#                        user_id             business_id  \
# 1       NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2       -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3       FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4       ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# 5       trf3Qcz8qvCDKXiTgjUcEg  7Rm9Ba50bw23KTA8RedZYg
# ...                        ...                     ...
# 908909  FowxkbAixI3hlREeCgIa_Q  kfNv-JZpuN6TVNSO6hHdkw
# 908911  1uxtQAuJ2T5Xwa_wp7kUnA  OaGf0Dp56ARhQwIDT90w_g
# 908912  v48Spe6WEpqehsF2xQADpg  hYnMeAO77RGyTtIzUSKYzQ
# 908913  ckqKGM2hl7I9Chp5IpAhkw  s2eyoTuJrcP7I_XyjdhUHQ
# 908914  4tF1CWdMxvvwpUIgGsDygA  _cb1Vg1NIWry8UA0jyuXnQ
#
#                                                      text                date  \
# 1       They have lots of good deserts and tasty cuban... 2013-02-05 18:35:10
# 2                  It's open even when you think it isn't 2013-08-18 00:56:08
# ...

# %%
filtered_tip_df.to_csv('yelp_tips.csv', index=False)

# %% [markdown]
# This dataset has no null values so we can just convert to csv and save.

# %% [markdown]
# ## Now we will move onto the reviews  ##
# This dataset is very large and so i'm having trouble reading it into a dataframe...

# %%
r_dtypes = {"stars": np.float16, 
            "useful": np.int32, 
            "funny": np.int32,
            "cool": np.int32}

# List to store filtered review chunks
filtered_chunks = []

# Filter reviews based on restaurant business IDs
with open("yelp_academic_dataset_review.json", "r") as f:
    reader = pd.read_json(f, orient="records", lines=True, dtype=r_dtypes, chunksize=1000)

    for chunk in reader:
        # Merge with restaurant dataset to filter reviews for restaurants only
        merged_chunk = pd.merge(chunk, res_df[['business_id']], on='business_id', how='inner')
        
        # Optionally perform additional filtering or drop unnecessary columns from merged_chunk
        
        # Append the filtered chunk to the list
        filtered_chunks.append(merged_chunk)

# Concatenate all filtered chunks into a single DataFrame
filtered_reviews = pd.concat(filtered_chunks, ignore_index=True)

# %%
filtered_reviews
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 2        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 3        HME_ksGph3se7Aze5hxa-Q  kSMOJwJXuEUqzfmuFncK4A
# 4        EJWyA5wpdVMji1j4TwSZqQ  mqBWACmaHflW4eh_Ofp16Q
# ...                         ...                     ...
# 5139692  7NgXAuTFiJHYbuepOPwU0w  x1QLCwZGFAjxRRw4EHc3-g
# 5139693  wD5ZWao_vjyT2h4xmGam8Q  7L7GL5Pi2cf8mbm2Dpw4zw
# 5139694  YVX1Wsa4LYxjvFwuHBb_gA  RKPkxOYQlM0BjhM-H6_vAw
# 5139695  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 5139696  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw    3.0       0      0     0
# 1        YjUWPpI6HXG530lwP-fb2A    3.0       0      0     0
# 2        kxX2SOes4o-D3ZQBkiMRfA    5.0       1      0     1
# ...

# %%
filtered_reviews.isna().sum()
# Out:
# review_id      0
# user_id        0
# business_id    0
# stars          0
# useful         0
# funny          0
# cool           0
# text           0
# date           0
# dtype: int64

# %%
filtered_reviews.to_csv('yelp_reviews.csv', index=False)

# %%
display(tip_df)
# Out:
#                        user_id             business_id  \
# 0       AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1       NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2       -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3       FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4       ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# ...                        ...                     ...
# 908910  eYodOTF8pkqKPzHkcxZs-Q  3lHTewuKFt5IImbXJoFeDQ
# 908911  1uxtQAuJ2T5Xwa_wp7kUnA  OaGf0Dp56ARhQwIDT90w_g
# 908912  v48Spe6WEpqehsF2xQADpg  hYnMeAO77RGyTtIzUSKYzQ
# 908913  ckqKGM2hl7I9Chp5IpAhkw  s2eyoTuJrcP7I_XyjdhUHQ
# 908914  4tF1CWdMxvvwpUIgGsDygA  _cb1Vg1NIWry8UA0jyuXnQ
#
#                                                      text                date  \
# 0                          Avengers time with the ladies. 2012-05-18 02:17:21
# 1       They have lots of good deserts and tasty cuban... 2013-02-05 18:35:10
# ...
